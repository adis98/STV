# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("results_comm.csv")

# %%
df
# Out:
#     Unnamed: 0  Features  Samples  Clients    NE Bytes  \
# 0            0        10       10        2      249328
# 1            1        10      100        2     1172368
# 2            2       100      100        2   193700368
# 3            3        10     1000        2    10402768
# 4            4       100     1000        2  1063474768
# 5            5        10       10        4      746384
# 6            6        10      100        4     2592464
# 7            7       100      100        4   580524944
# 8            8        10     1000        4    21053264
# 9            9       100     1000        4  2320073744
# 10          10        10       10        8     2477008
# 11          11        10      100        8     6169168
# 12          12       100      100        8  1933479568
# 13          13        10     1000        8    43090768
# 14          14       100     1000        8  5412577168
#
#     GD Bytes 10 iterations  GD Bytes 100 iterations  GD Bytes 1000 iterations
# ...

# %%
temp = df[df['Clients'] == 2]

# %% [markdown]
# clientscaling.values

# %%
temp
# Out:
#    Unnamed: 0  Features  Samples  Clients    NE Bytes  GD Bytes 10 iterations  \
# 0           0        10       10        2      249328                  116800
# 1           1        10      100        2     1172368                  980800
# 2           2       100      100        2   193700368                 9620800
# 3           3        10     1000        2    10402768                 9620800
# 4           4       100     1000        2  1063474768                96020800
#
#    GD Bytes 100 iterations  GD Bytes 1000 iterations
# 0                  1168000                  11680000
# 1                  9808000                  98080000
# 2                 96208000                 962080000
# 3                 96208000                 962080000
# 4                960208000                9602080000

# %%
temp.mean()
# Out:
# Unnamed: 0                  2.000000e+00
# Features                    4.600000e+01
# Samples                     4.420000e+02
# Clients                     2.000000e+00
# NE Bytes                    2.537999e+08
# GD Bytes 10 iterations      2.327200e+07
# GD Bytes 100 iterations     2.327200e+08
# GD Bytes 1000 iterations    2.327200e+09
# dtype: float64

# %%
temp = df[df['Clients'] == 4]

# %%
temp
# Out:
#    Unnamed: 0  Features  Samples  Clients    NE Bytes  GD Bytes 10 iterations  \
# 5           5        10       10        4      746384                  235840
# 6           6        10      100        4     2592464                 1963840
# 7           7       100      100        4   580524944                19243840
# 8           8        10     1000        4    21053264                19243840
# 9           9       100     1000        4  2320073744               192043840
#
#    GD Bytes 100 iterations  GD Bytes 1000 iterations
# 5                  2358400                  23584000
# 6                 19638400                 196384000
# 7                192438400                1924384000
# 8                192438400                1924384000
# 9               1920438400               19204384000

# %%
temp.mean()
# Out:
# Unnamed: 0                  7.000000e+00
# Features                    4.600000e+01
# Samples                     4.420000e+02
# Clients                     4.000000e+00
# NE Bytes                    5.849982e+08
# GD Bytes 10 iterations      4.654624e+07
# GD Bytes 100 iterations     4.654624e+08
# GD Bytes 1000 iterations    4.654624e+09
# dtype: float64

# %%
temp = df[df['Clients'] == 8]

# %%
temp
# Out:
#     Unnamed: 0  Features  Samples  Clients    NE Bytes  \
# 10          10        10       10        8     2477008
# 11          11        10      100        8     6169168
# 12          12       100      100        8  1933479568
# 13          13        10     1000        8    43090768
# 14          14       100     1000        8  5412577168
#
#     GD Bytes 10 iterations  GD Bytes 100 iterations  GD Bytes 1000 iterations
# 10                  473920                  4739200                  47392000
# 11                 3929920                 39299200                 392992000
# 12                38489920                384899200                3848992000
# 13                38489920                384899200                3848992000
# 14               384089920               3840899200               38408992000

# %%
temp.mean()
# Out:
# Unnamed: 0                  1.200000e+01
# Features                    4.600000e+01
# Samples                     4.420000e+02
# Clients                     8.000000e+00
# NE Bytes                    1.479559e+09
# GD Bytes 10 iterations      9.309472e+07
# GD Bytes 100 iterations     9.309472e+08
# GD Bytes 1000 iterations    9.309472e+09
# dtype: float64

# %%
temp = df[df['Features'] == 10]
temp
# Out:
#     Unnamed: 0  Features  Samples  Clients  NE Bytes  GD Bytes 10 iterations  \
# 0            0        10       10        2    249328                  116800
# 1            1        10      100        2   1172368                  980800
# 3            3        10     1000        2  10402768                 9620800
# 5            5        10       10        4    746384                  235840
# 6            6        10      100        4   2592464                 1963840
# 8            8        10     1000        4  21053264                19243840
# 10          10        10       10        8   2477008                  473920
# 11          11        10      100        8   6169168                 3929920
# 13          13        10     1000        8  43090768                38489920
#
#     GD Bytes 100 iterations  GD Bytes 1000 iterations
# 0                   1168000                  11680000
# 1                   9808000                  98080000
# ...

# %%
temp.mean()
# Out:
# Unnamed: 0                  6.333333e+00
# Features                    1.000000e+01
# Samples                     3.700000e+02
# Clients                     4.666667e+00
# NE Bytes                    9.772613e+06
# GD Bytes 10 iterations      8.339520e+06
# GD Bytes 100 iterations     8.339520e+07
# GD Bytes 1000 iterations    8.339520e+08
# dtype: float64

# %%
temp = df[df['Features'] == 100]
temp
# Out:
#     Unnamed: 0  Features  Samples  Clients    NE Bytes  \
# 2            2       100      100        2   193700368
# 4            4       100     1000        2  1063474768
# 7            7       100      100        4   580524944
# 9            9       100     1000        4  2320073744
# 12          12       100      100        8  1933479568
# 14          14       100     1000        8  5412577168
#
#     GD Bytes 10 iterations  GD Bytes 100 iterations  GD Bytes 1000 iterations
# 2                  9620800                 96208000                 962080000
# 4                 96020800                960208000                9602080000
# 7                 19243840                192438400                1924384000
# 9                192043840               1920438400               19204384000
# 12                38489920                384899200                3848992000
# 14               384089920               3840899200               38408992000

# %%
temp.mean()
# Out:
# Unnamed: 0                  8.000000e+00
# Features                    1.000000e+02
# Samples                     5.500000e+02
# Clients                     4.666667e+00
# NE Bytes                    1.917305e+09
# GD Bytes 10 iterations      1.232515e+08
# GD Bytes 100 iterations     1.232515e+09
# GD Bytes 1000 iterations    1.232515e+10
# dtype: float64

# %%
temp = df[df['Samples'] == 10]

# %%
temp
# Out:
#     Unnamed: 0  Features  Samples  Clients  NE Bytes  GD Bytes 10 iterations  \
# 0            0        10       10        2    249328                  116800
# 5            5        10       10        4    746384                  235840
# 10          10        10       10        8   2477008                  473920
#
#     GD Bytes 100 iterations  GD Bytes 1000 iterations
# 0                   1168000                  11680000
# 5                   2358400                  23584000
# 10                  4739200                  47392000

# %%
temp.mean()
# Out:
# Unnamed: 0                  5.000000e+00
# Features                    1.000000e+01
# Samples                     1.000000e+01
# Clients                     4.666667e+00
# NE Bytes                    1.157573e+06
# GD Bytes 10 iterations      2.755200e+05
# GD Bytes 100 iterations     2.755200e+06
# GD Bytes 1000 iterations    2.755200e+07
# dtype: float64

# %%
temp = df[df['Samples'] == 100]
temp
# Out:
#     Unnamed: 0  Features  Samples  Clients    NE Bytes  \
# 1            1        10      100        2     1172368
# 2            2       100      100        2   193700368
# 6            6        10      100        4     2592464
# 7            7       100      100        4   580524944
# 11          11        10      100        8     6169168
# 12          12       100      100        8  1933479568
#
#     GD Bytes 10 iterations  GD Bytes 100 iterations  GD Bytes 1000 iterations
# 1                   980800                  9808000                  98080000
# 2                  9620800                 96208000                 962080000
# 6                  1963840                 19638400                 196384000
# 7                 19243840                192438400                1924384000
# 11                 3929920                 39299200                 392992000
# 12                38489920                384899200                3848992000

# %%
temp.mean()
# Out:
# Unnamed: 0                  6.500000e+00
# Features                    5.500000e+01
# Samples                     1.000000e+02
# Clients                     4.666667e+00
# NE Bytes                    4.529398e+08
# GD Bytes 10 iterations      1.237152e+07
# GD Bytes 100 iterations     1.237152e+08
# GD Bytes 1000 iterations    1.237152e+09
# dtype: float64

# %%
temp = df[df['Samples'] == 1000]
temp
# Out:
#     Unnamed: 0  Features  Samples  Clients    NE Bytes  \
# 3            3        10     1000        2    10402768
# 4            4       100     1000        2  1063474768
# 8            8        10     1000        4    21053264
# 9            9       100     1000        4  2320073744
# 13          13        10     1000        8    43090768
# 14          14       100     1000        8  5412577168
#
#     GD Bytes 10 iterations  GD Bytes 100 iterations  GD Bytes 1000 iterations
# 3                  9620800                 96208000                 962080000
# 4                 96020800                960208000                9602080000
# 8                 19243840                192438400                1924384000
# 9                192043840               1920438400               19204384000
# 13                38489920                384899200                3848992000
# 14               384089920               3840899200               38408992000

# %%
temp.mean()
# Out:
# Unnamed: 0                  8.500000e+00
# Features                    5.500000e+01
# Samples                     1.000000e+03
# Clients                     4.666667e+00
# NE Bytes                    1.478445e+09
# GD Bytes 10 iterations      1.232515e+08
# GD Bytes 100 iterations     1.232515e+09
# GD Bytes 1000 iterations    1.232515e+10
# dtype: float64
